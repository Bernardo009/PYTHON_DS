# %%
import pandas as pd

df = pd.read_csv("Pedidos.csv")

df["Valor_venda"] = df["Unidades"] * df["PrecoUnidade"]

display(df)
# Out:
#      DataPedido    Regiao               Estado  Vendedor        Item  \
# 0    7-Jun-2016  Nordeste           Pernambuco    Tobias   Geladeira
# 1   11-Jul-2016  Nordeste              Paraíba     Nadia  Microondas
# 2   20-Jul-2016   Sudeste         Minas Gerais    Carlos   Geladeira
# 3   19-Jul-2016  Nordeste                Bahia     Tania  Microondas
# 4   16-Aug-2016   Sudeste       Rio de Janeiro     Pedro   Geladeira
# 5   22-Aug-2016  Nordeste              Alagoas    Tobias       Fogao
# 6   24-Aug-2016       Sul       Santa Catarina  Mauricio    Lavadora
# 7   10-Sep-2016   Sudeste         Minas Gerais     Smith    Lavadora
# 8   10-Sep-2016   Sudeste       Rio de Janeiro      Alan       Fogao
# 9   12-Sep-2016  Nordeste           Pernambuco    Tobias   Geladeira
# 10  26-Sep-2016       Sul    Rio Grande do Sul  Mauricio       Fogao
# 11  15-Oct-2016   Sudeste         Minas Gerais    Carlos  Microondas
# 12  14-Oct-2016       Sul    Rio Grande do Sul    Thomas  Microondas
# ...

# %%
import pandas as pd

# Vendedor com mais unidades vendidas.

vendedor = df.groupby("Vendedor")["Unidades"].sum().idxmax()

vendedor_qtd = df.groupby("Vendedor")["Unidades"].sum().max()


print(
    f"{vendedor} é o(a) vendedor(a) com mais unidades vendidas! Unidades vendidas: {vendedor_qtd}"
)
# Out:
# Tobias é o(a) vendedor(a) com mais unidades vendidas! Unidades vendidas 396

# %%
import pandas as pd

# Região com mais unidades vendidas.

regiao = df.groupby("Regiao")["Unidades"].sum().idxmax()

regiao_qtd = df.groupby("Regiao")["Unidades"].sum().max()


print(f"A região com mais unidades vendidas foi {regiao}: {regiao_qtd}")
# Out:
# A região com mais unidades vendidas foi Sudeste: 1199

# %%
import pandas as pd

#  Item com mais unidade vendidas.

itens = df.groupby("Item")["Unidades"].sum().idxmax()

itens_qtd = df.groupby("Item")["Unidades"].sum().max()


print(f"O item com mais unidades vendidas foi {itens}: {itens_qtd}")
# Out:
# O item com mais unidades vendidas foi Fogao: 994

# %%
import pandas as pd

#  Estado com mais unidade vendidas.

estado = df.groupby("Estado")["Unidades"].sum().idxmax()

estado_qtd = df.groupby("Estado")["Unidades"].sum().max()


print(f"O estado com mais unidades vendidas foi {estado}: {estado_qtd}")
# Out:
# O estado com mais unidades vendidas foi São Paulo: 755

# %%
import pandas as pd

# Maior valor de venda.

maior_valor = df["Valor_venda"].max()

print(f"O maior valor de venda foi {maior_valor}")
# Out:
# O maior valor de venda foi 178693.06

# %%
import pandas as pd

# Valor de venda por item.

valor_item = df.groupby("Item")["Valor_venda"].sum()

display(valor_item)
